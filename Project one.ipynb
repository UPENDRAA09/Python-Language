# %% [markdown]
# ##  This project uses the skills learnt from week 1 to week 6. The aim of this project is to create an English Dictionary app that returns definitions of English words. When the application is started, it displays a menu as follows:
#
# Main Menu
#
# Add a new word
#
# Find the meaning
#
# Update a word
#
# Exit
#
# Enter Choice:
#
# If item 1 is selected, it should prompt for a word and then accept its meaning. This pair of word and its meaning should be stored in a file called ‘words.txt’. When item 2 is selected, it should prompt for a word, search that word in the file ‘words.txt’ and return the meaning if it is found. If the meaning is not found, it should display an appropriate message. Similarly, when choice 3 is entered, it should accept a word and update its meaning. In all the above three cases, the prompt should return to the main menu. The words and their meanings should be stored as a dictionary in words.txt, using the concept of serialization. If choice 4 is selected, a graceful exit should be performed.
#
# If you want to be recognized as a professional programmer, you have to practice more and develop applications in Python which you can include in your online portfolio. To achieve this, one such comprehensive project (with two small sub-projects inside it) is added which have to be completed by every student.
#
# 1A: English Dictionary App
#
# This project uses the skills learnt from week 1 to week 6. The aim of this project is to create an English Dictionary app that returns definitions of English words.

# %%
#importing the json module for store dicitionary in json
import json
#creating the  python dicitionary
# words={}

#creating the  add new word and meaning function for adding a word and meaning in  dicitionary using English Dicitionary app
def add_new_word():
    word=input("Enter a Word:")
    meaning=input(f"Enter a Meanning of a {word}:")
    file=open("words.txt",'w')
    words[word]=meaning
    file.seek(0)
    json.dump(words,file)
    file.close()
    
#creating the finding  fucntion  to Finding the meaning of a specfic word in dicitionary using English Dicitionary app
def find_meaning_of_word():
    file=open('words.txt','r+')
    words=json.load(file)
    word_find= input('Enter a word to find the meaning in dicitionary: ')
    if word_find in words:
        print("Enter the y to display the word meaning which you searching for?")
        decide=input(f"enter the y->yes or n->no to display the meaning of a {word_find}:")
        if decide=="y":
            print(f"{word_find}:{words[word_find]}")
    else:
        print("Word  is  not found in the  English Dicitionary App")
    file.seek(0)
    file.close()
    
#creating the update fucntion to update the meaning of a specfic word in dicitionary,using English Dicitionary app   
# if present it will update the existing value otherwise it will add a new word and meaning to the dicitionary  
def update_the_word():
    file=open('words.txt','r+')
    word_find= input('Enter word to find: ')
    if word_find in words:
        print(f"{word_find} is present in English Dicitionary App")
        print("please add the word updated meaning to English Dicitionary App")
        meaning = input(f'Enter meaning for the {word_find} : ')
        words.update({word_find:meaning})
#         words[word_find]=meaning
    else:
        print(f"{word_find} is not present in English Dicitionary App")
        print("please add the word and meaning newly to English Dicitionary App")
        meaning = input(f'Enter meaning for the {word_find} : ')
        words[word_find]=meaning
    file.seek(0)
    json.dump(words,file)
    file.close()

#creating the exit fucntion to exit from dicitionary from English Dicitionary app     
def exit():
    print("You are now exit from the Dicitionary App!")
    print("Thank you for Using the English Dicitionary App!!!!")
    print("Thank you,Bye!!!")
    
#creating the mainu menu fucntion to execute the English Dicitionary app using choice with all function
def main_menu():
    while True:
        print("1:Add a new word\n2:Find the meaning\n3:Update a word\n4:Exit")
        choice=int(input("Enter the Choice:"))
        if choice==1:
            add_new_word()
        elif choice==2:
            find_meaning_of_word()
        elif choice==3:
            update_the_word()
        elif choice==4:
            print("Dicitionary app get exiting")
            print("Thank you for using the Dicitionary app")
            exit()
            break
        else:
            print("Invalid Input?")
            print("please! enter the valid Input Choice???")

#calling the main_menu() here            
main_menu()
# Out:
# 1:Add a new word
# 2:Find the meaning
# 3:Update a word
# 4:Exit
# Enter the Choice:1
# Enter a Word:hemp
# Enter a Meanning of a hemp:it is a seed
# 1:Add a new word
# 2:Find the meaning
# 3:Update a word
# 4:Exit
# Enter the Choice:2
# Enter a word to find the meaning in dicitionary: honey
# Word  is  not found in the  English Dicitionary App
# 1:Add a new word
# 2:Find the meaning
# 3:Update a word
# 4:Exit
# Enter the Choice:3
# Enter word to find: honey
# honey is not present in English Dicitionary App
# please add the word and meaning newly to English Dicitionary App
# Enter meaning for the honey : it is a sweet
# 1:Add a new word
# 2:Find the meaning
# 3:Update a word
# 4:Exit
# Enter the Choice:7
# Invalid Input?
# please! enter the valid Input Choice???
# 1:Add a new word
# 2:Find the meaning
# 3:Update a word
# 4:Exit
# Enter the Choice:4
# Dicitionary app get exiting
# Thank you for using the Dicitionary app
# You are now exit from the Dicitionary App!
# Thank you for Using the English Dicitionary App!!!!
# Thank you,Bye!!!

# %% [markdown]
# ## 1B: Library Book Management System
#
# In this project, a Library Book Management System will be implemented with the front end GUI developed using Tkinter and the backend database implemented in SQLite. It is a single window tkinter GUI application which will implement CRUD( create, read, update, delete) operations on a ‘books’ database, in SQLite. The window will contain text widgets to accept / display book title, author, year of publication, ISBN (optional) and a large text area/ list box to display the records which match the search criteria.

# %%
from tkinter import*
import sqlite3
import tkinter.ttk as ttk
import tkinter.messagebox as tkMessageBox

def Database():
    global conn,cursor
    conn=sqlite3.connect('project1.db')
    cursor=conn.cursor()
    cursor.execute("CREATE TABLE IF NOT EXISTS Book(Booktitle TEXT, Author TEXT, Year TEXT, ISBN TEXT)")
def Create():
    if Booktitle.get()=="" or Author.get()=="" or Year.get()=="":
        txt_result.config(text="Please enter all the fields",fg="red")
    else:
        Database()
        cursor.execute("Insert into book(Booktitle,Author,Year,ISBN) VALUES(?,?,?,?)",(str(Booktitle.get()),str(Author.get()),str(Year.get()),str(ISBN.get())))
        conn.commit()
        Booktitle.set("")
        Author.set("")
        Year.set("")
        ISBN.set("")
        cursor.close()
        conn.close()
        txt_result.config(text = "Record inserted Successfully!",fg = "green")
def Read():
    tree.delete(*tree.get_children())
    Database()
    cursor.execute("Select * From book ORDER BY Booktitle ASC")
    fetch=cursor.fetchall()
    for data in fetch:
        tree.insert('','end', values = (data[0],data[1],data[2],data[3]))
    cursor.close()
    txt_result.config(text = "Data Fetched Successfully!!", fg = "blue")
def Search():
    Database()
    cursor.execute("Select * From book where Booktitle = ? or Author = ? or Year = ? or ISBN = ?", (str(Booktitle.get()),str(Author.get()),str(Year.get()),str(ISBN.get())))
    fetch = cursor.fetchall()
    for data in fetch:
        tree.insert('','end', values = (data[0],data[1],data[2],data[3]))
    cursor.close()
    txt_result.config(text = "Searched data ",fg = "black")
    
def Issue():
    Database()
    txt_result.config(text="Book is Issue.Thank you",fg = "red")
    
def Delete():
    Database()
    cursor.execute("Delete From book where Booktitle = ? or Author = ? or Year = ? or ISBN= ?", (str(Booktitle.get()),str(Author.get()),str(Year.get()),str(ISBN.get())))
    cursor.close()
    txt_result.config(text = "Deleted Succssfully", fg = "red")
    
def Exit():
    result = tkMessageBox.askquestion("Do you Really want to Exit? (Y/N)", icon = "warning")
    if result == "yes":
        root.destroy()
        exit()
root=Tk()
root.geometry('1000x600')
root.title("A library Application!")
title_center=Frame(root,width=600,height=100,bd=8,bg="blue",relief="raise")
title_center.pack(side=TOP)
title_label=Label(title_center,text="..........Library Management Application..........",width=150,font=32)
title_label.pack()

# Variable Declaration:
Booktitle = StringVar()
Author = StringVar()
Year = StringVar()
ISBN = StringVar()

# FRAMES:
# Top = Frame(root, width = 900, height = 50, bd = 8, relief = "raise")
# Top.pack(side=TOP)
Left = Frame(root,width = 100,height = 100, bd = 8, relief = "raise",bg="Red")
Left.pack(side = LEFT)
Right = Frame(root,width = 100,height = 75, bd = 8, relief = "raise",bg="Yellow")
Right.pack(side = RIGHT)
Forms = Frame(Left, width = 300,height = 450)
Forms.pack(side = TOP)
Buttons = Frame(Left,width = 300,height = 100, bd = 8, relief = "raise")
Buttons.pack(side = BOTTOM)


# LABELS
# txt_title = Label(Top, width = 900, font = ('arial',24),text = "Library Book Management System")
# txt_title.pack()
txt_booktitle= Label(Forms, font = ('arial',16),text = "Book Title", bd = 15)
txt_booktitle.grid(row=0, stick = "e")
txt_author = Label(Forms,font=('arial',16),text = "Author", bd = 15)
txt_author.grid(row = 1,stick = "e")
txt_yop = Label(Forms,font=('arial',16),text = "Year", bd = 15)
txt_yop.grid(row = 2,stick = "e")
txt_isbn = Label(Forms,font=('arial',16),text="ISBN",bd = 15)
txt_isbn.grid(row = 3,stick = "e")

txt_result = Label(Buttons)
txt_result.pack(side = TOP)

# ENTRY
booktitle = Entry(Forms, textvariable = Booktitle, width=30)
booktitle.grid(row =0, column =1)
author = Entry(Forms, textvariable = Author, width=30)
author.grid(row =1, column =1)
yop = Entry(Forms, textvariable = Year, width=30)
yop.grid(row =2, column =1)
isbn = Entry(Forms, textvariable = ISBN, width=30)
isbn.grid(row =3, column =1)
# BUTTONS
btn_read = Button(Buttons,width = 10,text = 'Display',command=Read)
btn_read.pack(side=LEFT)

but_search = Button(Buttons,width = 10,text = 'Search',command=Search)
but_search.pack(side=LEFT)

btn_create = Button(Buttons, width = 10, text = "Add", command = Create)
btn_create.pack(side=LEFT)

but_issue = Button(Buttons,width = 10,text = 'Issue',command=Issue)
but_issue.pack(side=LEFT)

btn_delete = Button(Buttons,width = 10,text = 'Delete',command=Delete)
btn_delete.pack(side=LEFT)

btn_exit = Button(Buttons,width = 10,text = 'Exit',command=Exit)
btn_exit.pack(side=LEFT)
# LIST
scrollbary = Scrollbar(Right,orient=VERTICAL)
scrollbarx = Scrollbar(Right,orient=HORIZONTAL)

tree = ttk.Treeview(Right,columns=("Book Title","Author","Year","Isbn"))

scrollbary.config(command=tree.yview)
scrollbary.pack(side=RIGHT)

scrollbarx.config(command=tree.xview)
scrollbarx.pack(side=BOTTOM,fill=X)

tree.heading('Book Title',text="Booktitle",anchor=W)
tree.heading('Author',text="Author",anchor=W)
tree.heading('Year',text="Year",anchor=W)
tree.heading('Isbn',text="ISBN",anchor=W)

tree.column("#0",stretch=NO,minwidth=0,width=0)
tree.column("#1",stretch=NO,minwidth=0,width=100) 
tree.column("#2",stretch=NO,minwidth=0,width=60)
tree.column("#3",stretch=NO,minwidth=0,width=60)
tree.column("#4",stretch=NO,minwidth=0,width=80)
tree.pack()

# initialisation

root.mainloop()
